# %% [markdown]
# # Week 5 — Homework: Cross-Sectional Alpha Model v2 (Trees)
#
# **Course:** ML for Quantitative Finance
# **Due:** Before Week 6 lecture
#
# ---
#
# ## Objective
#
# Extend your Week 4 pipeline with tree-based models.
# Show the lift from nonlinear models and analyze with SHAP.
#
# ## Setup

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from scipy import stats
import xgboost as xgb
import lightgbm as lgb
import optuna
import shap
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 5)

# %% [markdown]
# ## Part 1: Extended Pipeline (15 pts)
#
# Reuse your Week 4 feature matrix (200+ stocks, 20+ features).
# Add XGBoost, LightGBM, and Random Forest to the model comparison.

# %%
# TODO: Load/rebuild Week 4 feature matrix
# TODO: Add XGBoost, LightGBM, RF to expanding-window pipeline

# %% [markdown]
# ## Part 2: Optuna Hyperparameter Tuning (25 pts)
#
# Tune XGBoost and LightGBM with Optuna:
# - At least 50 trials each
# - Use expanding-window time-series CV (never shuffle!)
# - Report best parameters and improvement over defaults

# %%
# TODO: Define Optuna objective with time-series CV
# TODO: Run 50+ trials for XGBoost
# TODO: Run 50+ trials for LightGBM
# TODO: Compare best tuned vs. default

# %% [markdown]
# ## Part 3: Full Model Comparison (20 pts)
#
# Compare all models: OLS, Ridge, Lasso, RF, XGBoost, LightGBM.
# Report:
# - Out-of-sample IC and R²
# - Portfolio Sharpe ratio (long-short top/bottom decile)
# - In-sample vs. out-of-sample IC gap (overfitting measure)

# %%
# TODO: Run all 6 models
# TODO: Create comprehensive comparison table
# TODO: Plot IC over time for all models

# %% [markdown]
# ## Part 4: SHAP Analysis (25 pts)
#
# For your best tree model:
# 1. Compute SHAP values
# 2. Create feature importance ranking
# 3. Identify the top 5 features
# 4. Create partial dependence plots for the top 3
# 5. Do they match known financial anomalies?

# %%
# TODO: SHAP analysis
# TODO: Summary plot
# TODO: Dependence plots
# TODO: Interpretation

# %% [markdown]
# ## Part 5: Overfitting Analysis (15 pts)
#
# 1. Plot in-sample vs. out-of-sample IC over time for each model.
# 2. Does the gap widen? Which model is most prone to overfitting?
# 3. **Stretch goal:** Implement a simple model combination (average predictions of top 3 models). Does it beat any single model?

# %%
# TODO: In-sample vs OOS IC comparison
# TODO: Model combination (average of top 3)
# TODO: Analysis
